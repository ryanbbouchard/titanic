# %% [markdown]
# # Exploratory Analysis of Titanic Dataset

# %%
# as of 20221014
x = 2
y = 3

# %%
print (x * y)
# Out:
# 6

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('titanic3.csv')

# %%
# data contains some unknown values that we want to replace with numpy NaN instead of '?', so we make that change and then update the data type
data.replace('?', np.nan, inplace = True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
# specify that we want 5 subplots of specif sizes; last plot variable indicates which plot column to populate the plot
fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
# replace strings with numerics to do correlations
data.replace({'male': 1, 'female': 0}, inplace=True)
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN
